# %%
from climdata import ClimData
from climdata.datasets.CMIPlocal import CMIPmirror

import xarray as xr
overrides = [
    "dataset=cmip",  # Select the MSWX dataset for extraction
    "region=europe",
    f"time_range.start_date=1989-01-01",  # Start date of extraction
    f"time_range.end_date=2014-12-31",    # End date of extraction
    "variables=[tasmin,tasmax,pr]",       # Variables to extract: min/max temperature & precipitation
    "data_dir=/data01/FDS/muduchuru/Atmos/",    # Local directory to store downloaded/intermediate files
    # Optional Google service account if needed for MSWX access
    # "dsinfo.mswx.params.google_service_account=./.climdata_conf/service.json",
    "index=tn10p",  # Extreme climate index to calculate
]

extractor = ClimData(overrides=overrides)
# ds = extractor.extract()

CMIP_extractor = CMIPmirror(extractor.cfg, experiments=['hist-aer'])

# %%
df_files = CMIP_extractor.fetch("/data01/FDS/muduchuru/Atmos/CMIP6/data/CMIP6",'day')
# Out:
# Indexing CMIP6 files:   0%|          | 0/1188 [00:00<?, ?it/s]

# %%
df_files['source_id'].unique()
# Out:
# array(['GFDL-ESM4', 'IPSL-CM6A-LR', 'BCC-CSM2-MR', 'HadGEM3-GC31-LL',
#        'CanESM5', 'CESM2', 'E3SM-2-0', 'FGOALS-g3', 'MIROC6',
#        'ACCESS-CM2', 'MPI-ESM1-2-LR', 'ACCESS-ESM1-5', 'CNRM-CM6-1'],
#       dtype=object)

# %%
df_files = CMIP_extractor.fetch("/data01/FDS/muduchuru/Atmos/CMIP6",'day')
# Out:
# Indexing CMIP6 files: 0it [00:00, ?it/s]

# %%
variable_id = 'tasmax'
source_id = 'HadGEM3-GC31-LL'
files = CMIP_extractor.df.query(f'variable_id=="{variable_id}"')['path'].values
xr.open_mfdataset(
    CMIP_extractor.df.query(f'variable_id=="{variable_id}" & source_id=="{source_id}"')['path'].values
)
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:    (time: 59400, bnds: 2, lat: 144, lon: 192)
# Coordinates:
#   * time       (time) object 475kB 1850-01-01 12:00:00 ... 2014-12-30 12:00:00
#   * lat        (lat) float64 1kB -89.38 -88.12 -86.88 ... 86.88 88.12 89.38
#   * lon        (lon) float64 2kB 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#     height     float64 8B 1.5
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object 950kB dask.array<chunksize=(1, 2), meta=np.ndarray>
#     lat_bnds   (time, lat, bnds) float64 137MB dask.array<chunksize=(36000, 144, 2), meta=np.ndarray>
#     lon_bnds   (time, lon, bnds) float64 182MB dask.array<chunksize=(36000, 192, 2), meta=np.ndarray>
#     tasmax     (time, lat, lon) float32 7GB dask.array<chunksize=(1, 144, 192), meta=np.ndarray>
# Attributes: (12/46)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
# ...

# %%
from climdata.utils.config import load_config
from climdata import AGRI_ISIMIP, ClimData
import xarray as xr

# Load default config with overrides
overrides = [
    "dataset=HYRAS",
    "region=germany",
    "variables=[et0]",
    "time_range.start_date=2015-01-01",
    "time_range.end_date=2026-12-31",
    "data_dir=/data01/FDS/muduchuru/Atmos/DWD",
]
extractor = ClimData(overrides=overrides)
extractor.extract()
# Out:
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/evaporation_fao/grids_germany_daily_evaporation_fao_2015_v1.1.nc
# ⬇️  Downloading: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/evaporation_fao/grids_germany_daily_evaporation_fao_2015_v1.1.nc
# ✅ Saved: /data01/FDS/muduchuru/Atmos/DWD/HYRAS/ET0/grids_germany_daily_evaporation_fao_2015_v1.1.nc
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/evaporation_fao/grids_germany_daily_evaporation_fao_2016_v1.1.nc
# ⬇️  Downloading: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/evaporation_fao/grids_germany_daily_evaporation_fao_2016_v1.1.nc
# ✅ Saved: /data01/FDS/muduchuru/Atmos/DWD/HYRAS/ET0/grids_germany_daily_evaporation_fao_2016_v1.1.nc
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/evaporation_fao/grids_germany_daily_evaporation_fao_2017_v1.1.nc
# ...
