# %%
import json
from climdata.extremes.indices import extreme_index 
geojson = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "coordinates": [
          13.246667038198012,
          52.891982026993958
        ],
        "type": "Point"
      }
    }
  ]
}


import climdata
clim_cfg, clim_ds = climdata.extract_data(
    overrides=[
            "dataset=hyras",
            "variables=['pr']",
            f"time_range.start_date=1989-01-01",
            f"time_range.end_date=2014-12-31",
            f"aoi='{json.dumps(geojson)}'",
            "dsinfo.mswx.params.google_service_account=./.climdata_conf/service.json",
    ]
,
save_to_file=False
)
clim_ds['pr'].attrs['units'] = "mm/day"
indices = extreme_index(clim_cfg, clim_ds)
index = indices.calculate('SPI1').compute()
index = index.compute()
# Out:
# ../../examples/conf
# False
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/hyras_de/precipitation/pr_hyras_1_1989_v6-0_de.nc
# ✔️  Exists locally: ./data/hyras/PR/pr_hyras_1_1989_v6-0_de.nc
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/hyras_de/precipitation/pr_hyras_1_1990_v6-0_de.nc
# ✔️  Exists locally: ./data/hyras/PR/pr_hyras_1_1990_v6-0_de.nc
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/hyras_de/precipitation/pr_hyras_1_1991_v6-0_de.nc
# ✔️  Exists locally: ./data/hyras/PR/pr_hyras_1_1991_v6-0_de.nc
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/hyras_de/precipitation/pr_hyras_1_1992_v6-0_de.nc
# ✔️  Exists locally: ./data/hyras/PR/pr_hyras_1_1992_v6-0_de.nc
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/hyras_de/precipitation/pr_hyras_1_1993_v6-0_de.nc
# ...

# %%
import json
from climdata.extremes.indices import extreme_index 

import climdata
clim_cfg, clim_ds = climdata.extract_data(
    overrides=[
            "dataset=hyras",
            "variables=['pr']",
            f"time_range.start_date=1989-01-01",
            f"time_range.end_date=2014-12-31",
            "bounds.custom={lat_min:50,lat_max:50.2,lon_min:8,lon_max:8.2}",
            "region=custom",
            "dsinfo.mswx.params.google_service_account=./.climdata_conf/service.json",
    ]
,
save_to_file=False
)
# clim_ds['pr'].attrs['units'] = "mm/day"
# indices = extreme_index(clim_cfg, clim_ds)
# index = indices.calculate('SPI1').compute()
# index = index.compute()
# Out:
# ../../examples/conf
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/hyras_de/precipitation/pr_hyras_1_1989_v6-0_de.nc
# ✔️  Exists locally: ./data/hyras/PR/pr_hyras_1_1989_v6-0_de.nc
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/hyras_de/precipitation/pr_hyras_1_1990_v6-0_de.nc
# ✔️  Exists locally: ./data/hyras/PR/pr_hyras_1_1990_v6-0_de.nc
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/hyras_de/precipitation/pr_hyras_1_1991_v6-0_de.nc
# ✔️  Exists locally: ./data/hyras/PR/pr_hyras_1_1991_v6-0_de.nc
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/hyras_de/precipitation/pr_hyras_1_1992_v6-0_de.nc
# ✔️  Exists locally: ./data/hyras/PR/pr_hyras_1_1992_v6-0_de.nc
# ⬇️  Checking: https://opendata.dwd.de/climate_environment/CDC/grids_germany/daily/hyras_de/precipitation/pr_hyras_1_1993_v6-0_de.nc
# ...

# %%
clim_ds['pr'].attrs['units'] = "mm/day"
indices = extreme_index(clim_cfg, clim_ds)
index = indices.calculate('SPI1').compute()
index = index.compute()
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x103305990>>
# Traceback (most recent call last):
#   File "/Users/kaushikreddy/miniconda3/envs/climenv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 781, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
clim_ds.to_netcdf("test.nc")
